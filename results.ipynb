# %% [markdown]
# # CURE - Clustering Using REpresentatives
#
# # Results

# %% [markdown]
# This notebook is dedicated to presenting comparisons between results that were achieved during our experiments with our CURE clustering algorithm implementation.
#
# The algorithm implementation was largerly inspired by [saurabhkumar2015](https://github.com/saurabhkumar2015)'s [repository](https://github.com/saurabhkumar2015/CureAlgorithm).
#
# Happy reading and feel free to contact us for any further details.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Results - w/o outliers

# %% [markdown]
# <font color=orange>_TODO: fill this_</font>

# %% [markdown]
# <font color=orange>CURRENTLY TESTING</font>

# %%
cols = ['dim1', 'dim2', 'cluster']

df = pd.read_csv('cureOutput_1622491061083/part-00000', header=None)\
.append(pd.read_csv('cureOutput_1622491061083/part-00001', header=None))\
.reset_index(drop=True)
df.columns = cols

reps = pd.read_csv('cureOutput_1622491061083/representatives.txt', header=None, names=cols)
means = pd.read_csv('cureOutput_1622491061083/means.txt', header=None, names=cols)
data_means = df.groupby('cluster').mean()

plt.figure(figsize=(12, 12))
plt.scatter(df['dim1'], df['dim2'], c=df['cluster'])
sns.scatterplot(x='dim1', y='dim2', hue='cluster', s=200, data=reps)
sns.scatterplot(x='dim1', y='dim2', hue='cluster', s=250, marker='P', data=means, legend=False)
sns.scatterplot(x='dim1', y='dim2', hue='cluster', s=350, marker='*', data=data_means, legend=False)
plt.show()

# %%
cols = ['dim1', 'dim2', 'cluster']

df = pd.read_csv('cureOutput_1622495427136//part-00000', header=None)\
.append(pd.read_csv('cureOutput_1622495427136/part-00001', header=None))\
.reset_index(drop=True)
df.columns = cols

reps = pd.read_csv('cureOutput_1622495427136/representatives.txt', header=None, names=cols)
means = pd.read_csv('cureOutput_1622495427136/means.txt', header=None, names=cols)
data_means = df.groupby('cluster').mean()

plt.figure(figsize=(12, 12))
plt.scatter(df['dim1'], df['dim2'], c=df['cluster'])
sns.scatterplot(x='dim1', y='dim2', hue='cluster', s=200, data=reps)
sns.scatterplot(x='dim1', y='dim2', hue='cluster', s=250, marker='P', data=means, legend=False)
sns.scatterplot(x='dim1', y='dim2', hue='cluster', s=350, marker='*', data=data_means, legend=False)
plt.show()

# %%
cols = ['dim1', 'dim2', 'cluster']

df = pd.read_csv('cureOutput_1622495562334/part-00000', header=None)\
.append(pd.read_csv('cureOutput_1622495562334/part-00001', header=None))\
.reset_index(drop=True)
df.columns = cols

reps = pd.read_csv('cureOutput_1622495562334/representatives.txt', header=None, names=cols)
means = pd.read_csv('cureOutput_1622495562334/means.txt', header=None, names=cols)
data_means = df.groupby('cluster').mean()

plt.figure(figsize=(12, 12))
plt.scatter(df['dim1'], df['dim2'], c=df['cluster'])
sns.scatterplot(x='dim1', y='dim2', hue='cluster', s=200, data=reps)
sns.scatterplot(x='dim1', y='dim2', hue='cluster', s=250, marker='P', data=means, legend=False)
sns.scatterplot(x='dim1', y='dim2', hue='cluster', s=350, marker='*', data=data_means, legend=False)
plt.show()

# %%
cols = ['dim1', 'dim2', 'cluster']

df = pd.read_csv('cureOutput_1622496186335/part-00000', header=None)\
.append(pd.read_csv('cureOutput_1622496186335/part-00001', header=None))\
.reset_index(drop=True)
df.columns = cols

reps = pd.read_csv('cureOutput_1622496186335/representatives.txt', header=None, names=cols)
means = pd.read_csv('cureOutput_1622496186335/means.txt', header=None, names=cols)
data_means = df.groupby('cluster').mean()

plt.figure(figsize=(12, 12))
plt.scatter(df['dim1'], df['dim2'], c=df['cluster'])
sns.scatterplot(x='dim1', y='dim2', hue='cluster', s=200, data=reps)
sns.scatterplot(x='dim1', y='dim2', hue='cluster', s=250, marker='P', data=means, legend=False)
sns.scatterplot(x='dim1', y='dim2', hue='cluster', s=350, marker='*', data=data_means, legend=False)
plt.show()

# %%
cols = ['dim1', 'dim2', 'cluster']

df = pd.read_csv('cureOutput_1622496387993/part-00000', header=None)\
.append(pd.read_csv('cureOutput_1622496387993/part-00001', header=None))\
.reset_index(drop=True)
df.columns = cols

reps = pd.read_csv('cureOutput_1622496387993/representatives.txt', header=None, names=cols)
means = pd.read_csv('cureOutput_1622496387993/means.txt', header=None, names=cols)
data_means = df.groupby('cluster').mean()

plt.figure(figsize=(12, 12))
plt.scatter(df['dim1'], df['dim2'], c=df['cluster'])
sns.scatterplot(x='dim1', y='dim2', hue='cluster', s=200, data=reps)
sns.scatterplot(x='dim1', y='dim2', hue='cluster', s=250, marker='P', data=means, legend=False)
sns.scatterplot(x='dim1', y='dim2', hue='cluster', s=350, marker='*', data=data_means, legend=False)
plt.show()

# %%
cols = ['dim1', 'dim2', 'cluster']

df = pd.read_csv('kmeansAgglomerativeOutput_1622508375649/results.txt', header=None)\
.reset_index(drop=True)
df.columns = cols

# reps = pd.read_csv('cureOutput_1622495427136/representatives.txt', header=None, names=cols)
# means = pd.read_csv('cureOutput_1622495427136/means.txt', header=None, names=cols)
data_means = df.groupby('cluster').mean()

plt.figure(figsize=(12, 12))
plt.scatter(df['dim1'], df['dim2'], c=df['cluster'])
# sns.scatterplot(x='dim1', y='dim2', hue='cluster', s=200, data=reps)
# sns.scatterplot(x='dim1', y='dim2', hue='cluster', s=250, marker='P', data=means, legend=False)
sns.scatterplot(x='dim1', y='dim2', hue='cluster', s=350, marker='*', data=data_means, legend=False)
plt.show()

# %% [markdown]
# ## Results - KMeans & Hierarchical

# %% [markdown]
# <font color=orange>_TODO: fill this_</font>

# %% [markdown]
# ## Results - w/ outliers

# %% [markdown]
# <font color=orange>_TODO: fill this_</font>
